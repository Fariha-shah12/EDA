# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Claims.csv')
df.head(4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    CL.CLIENT_ID||CL.EMPLOYEE_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE  \
# 0                  4.334000e+10        547344     Dependent            S
# 1                  4.334000e+10        816550     Dependent            S
# 2                  4.334000e+10        508897  Main Insured            MF
# 3                  4.334000e+10        508900  Main Insured            MF
#
#     AGE POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0   2.0         01-Jul-17          30-Jun-18      10000            400000
# 1   4.0         01-Jul-19          30-Jun-20      10000            400000
# 2  36.0         01-Jul-17          30-Jun-18      10000            400000
# ...

# %%
df =df.drop(['Unnamed: 18','Unnamed: 19'], axis = 1)
df.head()
# Out:
#    CL.CLIENT_ID||CL.EMPLOYEE_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE  \
# 0                  4.334000e+10        547344     Dependent            S
# 1                  4.334000e+10        816550     Dependent            S
# 2                  4.334000e+10        508897  Main Insured            MF
# 3                  4.334000e+10        508900  Main Insured            MF
# 4                  4.334000e+10        369250     Dependent            D
#
#     AGE POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0   2.0         01-Jul-17          30-Jun-18      10000            400000
# 1   4.0         01-Jul-19          30-Jun-20      10000            400000
# 2  36.0         01-Jul-17          30-Jun-18      10000            400000
# 3  36.0         01-Jul-17          30-Jun-18      10000            400000
# 4   0.0         01-Jul-16          30-Jun-17      10000            400000
#
#   PATIENT_ADMISSION_DATE PATIENT_DISCHARGE_DATE DISEASE_PARENT_CD  \
# ...

# %%
df.isnull().sum()
# Out:
# CL.CLIENT_ID||CL.EMPLOYEE_ID       0
# CLAIM_REG_NO                       0
# LIFE_ASURED                        0
# RELATION_CODE                      1
# AGE                                1
# POLICY_START_DATE                  0
# POLICY_EXPIRE_DATE                 0
# ROOM_RENT                          0
# TOTAL_LIMIT_INDI                   0
# PATIENT_ADMISSION_DATE             0
# PATIENT_DISCHARGE_DATE          2927
# DISEASE_PARENT_CD                  0
# DISEASE_CHILD_CD                   0
# PROC_PARENT_CD                     0
# PROC_CHILD_CD                      0
# HOSPITAL_NAME                      0
# CITY_NAME                          0
# APV_TOTAL                          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378969 entries, 0 to 378968
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   CL.CLIENT_ID||CL.EMPLOYEE_ID  378969 non-null  float64
#  1   CLAIM_REG_NO                  378969 non-null  int64
#  2   LIFE_ASURED                   378969 non-null  object
#  3   RELATION_CODE                 378968 non-null  object
#  4   AGE                           378968 non-null  float64
#  5   POLICY_START_DATE             378969 non-null  object
#  6   POLICY_EXPIRE_DATE            378969 non-null  object
#  7   ROOM_RENT                     378969 non-null  int64
#  8   TOTAL_LIMIT_INDI              378969 non-null  int64
#  9   PATIENT_ADMISSION_DATE        378969 non-null  object
#  10  PATIENT_DISCHARGE_DATE        376042 non-null  object
#  11  DISEASE_PARENT_CD             378969 non-null  object
# ...

# %% [markdown]
# # Data Cleaning

# %%
df['POLICY_START_DATE']=pd.to_datetime(df['POLICY_START_DATE'])
df
# Out:
#         CL.CLIENT_ID||CL.EMPLOYEE_ID  CLAIM_REG_NO   LIFE_ASURED  \
# 0                       4.334000e+10        547344     Dependent
# 1                       4.334000e+10        816550     Dependent
# 2                       4.334000e+10        508897  Main Insured
# 3                       4.334000e+10        508900  Main Insured
# 4                       4.334000e+10        369250     Dependent
# ...                              ...           ...           ...
# 378964                  9.062100e+11        640472  Main Insured
# 378965                  9.078000e+11        939086  Main Insured
# 378966                  9.079400e+11        855992  Main Insured
# 378967                  9.079400e+11       1040858  Main Insured
# 378968                  9.079400e+11       1076283  Main Insured
#
#        RELATION_CODE   AGE POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  \
# 0                 S    2.0        2017-07-01          30-Jun-18      10000
# ...

# %%
df['POLICY_EXPIRE_DATE']=pd.to_datetime(df['POLICY_EXPIRE_DATE'])
df
# Out:
#         CL.CLIENT_ID||CL.EMPLOYEE_ID  CLAIM_REG_NO   LIFE_ASURED  \
# 0                       4.334000e+10        547344     Dependent
# 1                       4.334000e+10        816550     Dependent
# 2                       4.334000e+10        508897  Main Insured
# 3                       4.334000e+10        508900  Main Insured
# 4                       4.334000e+10        369250     Dependent
# ...                              ...           ...           ...
# 378964                  9.062100e+11        640472  Main Insured
# 378965                  9.078000e+11        939086  Main Insured
# 378966                  9.079400e+11        855992  Main Insured
# 378967                  9.079400e+11       1040858  Main Insured
# 378968                  9.079400e+11       1076283  Main Insured
#
#        RELATION_CODE   AGE POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  \
# 0                 S    2.0        2017-07-01         2018-06-30      10000
# ...

# %%
df['PATIENT_ADMISSION_DATE']=pd.to_datetime(df['PATIENT_ADMISSION_DATE'])
df
# Out:
#         CL.CLIENT_ID||CL.EMPLOYEE_ID  CLAIM_REG_NO   LIFE_ASURED  \
# 0                       4.334000e+10        547344     Dependent
# 1                       4.334000e+10        816550     Dependent
# 2                       4.334000e+10        508897  Main Insured
# 3                       4.334000e+10        508900  Main Insured
# 4                       4.334000e+10        369250     Dependent
# ...                              ...           ...           ...
# 378964                  9.062100e+11        640472  Main Insured
# 378965                  9.078000e+11        939086  Main Insured
# 378966                  9.079400e+11        855992  Main Insured
# 378967                  9.079400e+11       1040858  Main Insured
# 378968                  9.079400e+11       1076283  Main Insured
#
#        RELATION_CODE   AGE POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  \
# 0                 S    2.0        2017-07-01         2018-06-30      10000
# ...

# %%
df['PATIENT_DISCHARGE_DATE']=pd.to_datetime(df['PATIENT_DISCHARGE_DATE'])
df
# Out:
#         CL.CLIENT_ID||CL.EMPLOYEE_ID  CLAIM_REG_NO   LIFE_ASURED  \
# 0                       4.334000e+10        547344     Dependent
# 1                       4.334000e+10        816550     Dependent
# 2                       4.334000e+10        508897  Main Insured
# 3                       4.334000e+10        508900  Main Insured
# 4                       4.334000e+10        369250     Dependent
# ...                              ...           ...           ...
# 378964                  9.062100e+11        640472  Main Insured
# 378965                  9.078000e+11        939086  Main Insured
# 378966                  9.079400e+11        855992  Main Insured
# 378967                  9.079400e+11       1040858  Main Insured
# 378968                  9.079400e+11       1076283  Main Insured
#
#        RELATION_CODE   AGE POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  \
# 0                 S    2.0        2017-07-01         2018-06-30      10000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378969 entries, 0 to 378968
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   CL.CLIENT_ID||CL.EMPLOYEE_ID  378969 non-null  float64
#  1   CLAIM_REG_NO                  378969 non-null  int64
#  2   LIFE_ASURED                   378969 non-null  object
#  3   RELATION_CODE                 378968 non-null  object
#  4   AGE                           378968 non-null  float64
#  5   POLICY_START_DATE             378969 non-null  datetime64[ns]
#  6   POLICY_EXPIRE_DATE            378969 non-null  datetime64[ns]
#  7   ROOM_RENT                     378969 non-null  int64
#  8   TOTAL_LIMIT_INDI              378969 non-null  int64
#  9   PATIENT_ADMISSION_DATE        378969 non-null  datetime64[ns]
#  10  PATIENT_DISCHARGE_DATE        376042 non-null  datetime64[ns]
#  11  DISEASE_PARENT_CD             378969 non-null  object
# ...

# %%
df.rename(columns = {'CL.CLIENT_ID||CL.EMPLOYEE_ID':'Client_ID'}, inplace = True)
df.head()
# Out:
#       Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0  4.334000e+10        547344     Dependent            S    2.0
# 1  4.334000e+10        816550     Dependent            S    4.0
# 2  4.334000e+10        508897  Main Insured            MF  36.0
# 3  4.334000e+10        508900  Main Insured            MF  36.0
# 4  4.334000e+10        369250     Dependent            D    0.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
# 2        2017-07-01         2018-06-30      10000            400000
# 3        2017-07-01         2018-06-30      10000            400000
# 4        2016-07-01         2017-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE PATIENT_DISCHARGE_DATE DISEASE_PARENT_CD  \
# 0             2018-04-09             2018-04-09               Z04
# ...

# %%
df['LIFE_ASURED']=df['LIFE_ASURED'].astype('string')
df['LIFE_ASURED'].dtype
# Out:
# StringDtype

# %%
df['RELATION_CODE']=df['RELATION_CODE'].astype('string')
df['RELATION_CODE'].dtype
# Out:
# StringDtype

# %%
df['DISEASE_PARENT_CD']=df['DISEASE_PARENT_CD'].astype('string')
df['DISEASE_PARENT_CD'].dtype
# Out:
# StringDtype

# %%
df['DISEASE_CHILD_CD']=df['DISEASE_CHILD_CD'].astype('string')
df['DISEASE_CHILD_CD'].dtype
# Out:
# StringDtype

# %%
df['PROC_PARENT_CD']=df['PROC_PARENT_CD'].astype('string')
df['PROC_PARENT_CD'].dtype
# Out:
# StringDtype

# %%
df['PROC_CHILD_CD']=df['PROC_CHILD_CD'].astype('string')
df['PROC_CHILD_CD'].dtype
# Out:
# StringDtype

# %%
df['HOSPITAL_NAME']=df['HOSPITAL_NAME'].astype('string')
df['HOSPITAL_NAME'].dtype
# Out:
# StringDtype

# %%
df['CITY_NAME']=df['CITY_NAME'].astype('string')
df['CITY_NAME'].dtype
# Out:
# StringDtype

# %%
df['APV_TOTAL'] = df['APV_TOTAL'].replace(['GILGIT'],0)

# %%
df['APV_TOTAL']=df['APV_TOTAL'].astype('float')
df['APV_TOTAL'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378969 entries, 0 to 378968
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Client_ID               378969 non-null  float64
#  1   CLAIM_REG_NO            378969 non-null  int64
#  2   LIFE_ASURED             378969 non-null  string
#  3   RELATION_CODE           378968 non-null  string
#  4   AGE                     378968 non-null  float64
#  5   POLICY_START_DATE       378969 non-null  datetime64[ns]
#  6   POLICY_EXPIRE_DATE      378969 non-null  datetime64[ns]
#  7   ROOM_RENT               378969 non-null  int64
#  8   TOTAL_LIMIT_INDI        378969 non-null  int64
#  9   PATIENT_ADMISSION_DATE  378969 non-null  datetime64[ns]
#  10  PATIENT_DISCHARGE_DATE  376042 non-null  datetime64[ns]
#  11  DISEASE_PARENT_CD       378969 non-null  string
#  12  DISEASE_CHILD_CD        378969 non-null  string
# ...

# %%
df.head()
# Out:
#       Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0  4.334000e+10        547344     Dependent            S    2.0
# 1  4.334000e+10        816550     Dependent            S    4.0
# 2  4.334000e+10        508897  Main Insured            MF  36.0
# 3  4.334000e+10        508900  Main Insured            MF  36.0
# 4  4.334000e+10        369250     Dependent            D    0.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
# 2        2017-07-01         2018-06-30      10000            400000
# 3        2017-07-01         2018-06-30      10000            400000
# 4        2016-07-01         2017-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE PATIENT_DISCHARGE_DATE DISEASE_PARENT_CD  \
# 0             2018-04-09             2018-04-09               Z04
# ...

# %%
df.head(3)
# Out:
#       Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0  4.334000e+10        547344     Dependent            S    2.0
# 1  4.334000e+10        816550     Dependent            S    4.0
# 2  4.334000e+10        508897  Main Insured            MF  36.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
# 2        2017-07-01         2018-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE PATIENT_DISCHARGE_DATE DISEASE_PARENT_CD  \
# 0             2018-04-09             2018-04-09               Z04
# 1             2019-12-04             2019-12-05               J35
# 2             2018-01-16             2018-01-16             Z9881
#
#   DISEASE_CHILD_CD PROC_PARENT_CD PROC_CHILD_CD  \
# 0             Z041            JLP          JLP1
# 1             J352            0CN       0CNQXZZ
# ...

# %%
What work was done here

map karwaya hay cparent code ko main df say

# %%
parent_disease=pd.read_csv('D:\MS-material\IDS\Health Data\Lookup Tables\Parent Disease_codes.csv')
mapping = dict(parent_disease[['MDC_CODE', 'DISEASE_DESC']].values)
mapping
# Out:
# {'A00': 'Cholera, Cholera',
#  'A01': 'Typhoid and paratyphoid fevers, Typhoid and paratyphoid fevers',
#  'A010': 'Typhoid fever, Typhoid fever',
#  'A02': 'Other salmonella infections, Other salmonella infections',
#  'A022': 'Localized salmonella infections, Localized salmonella infections',
#  'A03': 'Shigellosis, Shigellosis',
#  'A04': 'Other bacterial intestinal infections, Other bacterial intestinal infections',
#  'A05': 'Oth bacterial foodborne intoxications| NEC, Other bacterial foodborne intoxications| not elsewhere classified',
#  'A06': 'Amebiasis, Amebiasis',
#  'A068': 'Amebic infection of other sites, Amebic infection of other sites',
#  'A07': 'Other protozoal intestinal diseases, Other protozoal intestinal diseases',
#  'A08': 'Viral and other specified intestinal infections, Viral and other specified intestinal infections',
# ...

# %%
df['Parent_Disease_Name'] = df['DISEASE_PARENT_CD'].map(mapping)
df.head(2)
# Out:
#       Client_ID  CLAIM_REG_NO LIFE_ASURED RELATION_CODE  AGE  \
# 0  4.334000e+10        547344   Dependent            S   2.0
# 1  4.334000e+10        816550   Dependent            S   4.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE PATIENT_DISCHARGE_DATE DISEASE_PARENT_CD  \
# 0             2018-04-09             2018-04-09               Z04
# 1             2019-12-04             2019-12-05               J35
#
#   DISEASE_CHILD_CD PROC_PARENT_CD PROC_CHILD_CD  \
# 0             Z041            JLP          JLP1
# 1             J352            0CN       0CNQXZZ
#
#                                        HOSPITAL_NAME  CITY_NAME  APV_TOTAL  \
# 0                       NON-PANEL HOPSITAL-ISLAMABAD  ISLAMABAD    82000.0
# ...

# %%
child_procedure=pd.read_csv('D:\MS-material\IDS\Health Data\Lookup Tables\Child_procedure_codes.csv')
mapping = dict(child_procedure[['PROC_CODE', 'CATAGORY']].values)
mapping
# Out:
# {'0016070': 'Bypass Cereb Vent to Nasophar with Autol Sub| Open ApproachBypass Cerebral Ventricle to Nasopharynx with Autologous Tissue Substitute| Open Approach',
#  '0016071': 'Bypass Cereb Vent to Mastoid Sinus w Autol Sub| OpenBypass Cerebral Ventricle to Mastoid Sinus with Autologous Tissue Substitute| Open Approach',
#  '0016072': 'Bypass Cereb Vent to Atrium with Autol Sub| Open ApproachBypass Cerebral Ventricle to Atrium with Autologous Tissue Substitute| Open Approach',
#  '0016073': 'Bypass Cereb Vent to Blood Vess w Autol Sub| OpenBypass Cerebral Ventricle to Blood Vessel with Autologous Tissue Substitute| Open Approach',
#  '0016074': 'Bypass Cereb Vent to Pleural Cav w Autol Sub| OpenBypass Cerebral Ventricle to Pleural Cavity with Autologous Tissue Substitute| Open Approach',
#  '0016075': 'Bypass Cereb Vent to Intestine with Autol Sub| Open ApproachBypass Cerebral Ventricle to Intestine with Autologous Tissue Substitute| Open Approach',
# ...

# %%
df['Child_Procedure_Name'] = df['PROC_CHILD_CD'].map(mapping)
df.head(2)
# Out:
#       Client_ID  CLAIM_REG_NO LIFE_ASURED RELATION_CODE  AGE  \
# 0  4.334000e+10        547344   Dependent            S   2.0
# 1  4.334000e+10        816550   Dependent            S   4.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE PATIENT_DISCHARGE_DATE DISEASE_PARENT_CD  \
# 0             2018-04-09             2018-04-09               Z04
# 1             2019-12-04             2019-12-05               J35
#
#   DISEASE_CHILD_CD PROC_PARENT_CD PROC_CHILD_CD  \
# 0             Z041            JLP          JLP1
# 1             J352            0CN       0CNQXZZ
#
#                                        HOSPITAL_NAME  CITY_NAME  APV_TOTAL  \
# 0                       NON-PANEL HOPSITAL-ISLAMABAD  ISLAMABAD    82000.0
# ...

# %%
parent_procedure=pd.read_csv('D:\MS-material\IDS\Health Data\Lookup Tables\Parent_procedure_codes.csv')
mapping = dict(parent_procedure[['PROC_CODE', 'PROC_DESCRIPTION']].values)
mapping
# Out:
# {'1': 'Central Nervous System| Bypass,Central Nervous System| Bypass',
#  '2': 'Central Nervous System| Change,Central Nervous System| Change',
#  '3': 'Administration| Physiological Sys & Anatomical Regions| Intr,Administration| Physiological Systems and Anatomical Regions| Introduction',
#  '5': 'Central Nervous System| Destruction,Central Nervous System| Destruction',
#  '8': 'Central Nervous System| Division,Central Nervous System| Division',
#  '8E0': 'Oth proc| Physiological Sys & Anatomical Regions| Other Proc,Other Procedures| Physiological Systems and Anatomical Regions| Other Procedures',
#  '9': 'Central Nervous System| Drainage,Central Nervous System| Drainage',
#  '12': 'Peripheral Nervous System| Change,Peripheral Nervous System| Change',
#  '15': 'Peripheral Nervous System| Destruction,Peripheral Nervous System| Destruction',
#  '18': 'Peripheral Nervous System| Division,Peripheral Nervous System| Division',
# ...

# %%
df['Parent_Procedure_Name'] = df['PROC_PARENT_CD'].map(mapping)
df.head(2)
# Out:
#       Client_ID  CLAIM_REG_NO LIFE_ASURED RELATION_CODE  AGE  \
# 0  4.334000e+10        547344   Dependent            S   2.0
# 1  4.334000e+10        816550   Dependent            S   4.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE  ... DISEASE_PARENT_CD DISEASE_CHILD_CD  \
# 0             2018-04-09  ...               Z04             Z041
# 1             2019-12-04  ...               J35             J352
#
#   PROC_PARENT_CD PROC_CHILD_CD  \
# 0            JLP          JLP1
# 1            0CN       0CNQXZZ
#
#                                        HOSPITAL_NAME  CITY_NAME APV_TOTAL  \
# 0                       NON-PANEL HOPSITAL-ISLAMABAD  ISLAMABAD   82000.0
# 1  GLOBAL HEALTH SERVICES-QUAID-E-AZAM INTERNATIO...  ISLAMABAD  122685.0
#
# ...

# %%
child_disease=pd.read_csv('D:\MS-material\IDS\Health Data\Lookup Tables\child_disease_codes.csv')
mapping = dict(child_disease[['MDC_CODE', 'CATAGORY']].values)
mapping
# Out:
# {'A548': 'Other gonococcal infectionsOther gonococcal infections',
#  'A56': 'Other sexually transmitted chlamydial diseasesOther sexually transmitted chlamydial diseases',
#  'A560': 'Chlamydial infection of lower genitourinary tractChlamydial infection of lower genitourinary tract',
#  'A561': 'Chlamydial infection of pelviperitoneum and oth GU organsChlamydial infection of pelviperitoneum and other genitourinary organs',
#  'A59': 'TrichomoniasisTrichomoniasis',
#  'A590': 'Urogenital trichomoniasisUrogenital trichomoniasis',
#  'A60': 'Anogenital herpesviral [herpes simplex] infectionsAnogenital herpesviral [herpes simplex] infections',
#  'A600': 'Herpesviral infection of genitalia and urogenital tractHerpesviral infection of genitalia and urogenital tract',
#  'A63': 'Oth predominantly sexually transmitted diseases| NECOther predominantly sexually transmitted diseases| not elsewhere classified',
#  'A66': 'YawsYaws',
#  'A67': 'Pinta [carate]Pinta [carate]',
# ...

# %%
df['Child_Disease_Name'] = df['DISEASE_CHILD_CD'].map(mapping)
df.head(1000)
# Out:
#         Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0    4.334000e+10        547344     Dependent            S    2.0
# 1    4.334000e+10        816550     Dependent            S    4.0
# 2    4.334000e+10        508897  Main Insured            MF  36.0
# 3    4.334000e+10        508900  Main Insured            MF  36.0
# 4    4.334000e+10        369250     Dependent            D    0.0
# ..            ...           ...           ...           ...   ...
# 995  4.350000e+10        412008  Main Insured            M   58.0
# 996  4.350000e+10        441348  Main Insured            M   58.0
# 997  4.350000e+10        459442  Main Insured            M   58.0
# 998  4.350000e+10        509217  Main Insured            M   59.0
# 999  4.350000e+10        537889  Main Insured            M   59.0
#
#     POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0          2017-07-01         2018-06-30      10000            400000
# ...

# %%
child_disease = pd.DataFrame(mapping.items(), columns=['DCC', 'DiseaseDescription'])

# %%
child_disease
# Out:
#           DCC                                 DiseaseDescription
# 0        A548  Other gonococcal infectionsOther gonococcal in...
# 1         A56  Other sexually transmitted chlamydial diseases...
# 2        A560  Chlamydial infection of lower genitourinary tr...
# 3        A561  Chlamydial infection of pelviperitoneum and ot...
# 4         A59                       TrichomoniasisTrichomoniasis
# ...       ...                                                ...
# 21910   Y3754  Military op w nuclear radiation effects of nuc...
# 21911  Y37540  Miltry op w nuclear radiation eff of nuclear w...
# 21912  Y37541  Miltry op w nuclear radiation effects of nucle...
# 21913   Y3759  Military operation involving oth effects of nu...
# 21914  Y37590  Military operation w oth effects of nuclear we...
#
# [21915 rows x 2 columns]

# %%
df
# Out:
#            Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0       4.334000e+10        547344     Dependent            S    2.0
# 1       4.334000e+10        816550     Dependent            S    4.0
# 2       4.334000e+10        508897  Main Insured            MF  36.0
# 3       4.334000e+10        508900  Main Insured            MF  36.0
# 4       4.334000e+10        369250     Dependent            D    0.0
# ...              ...           ...           ...           ...   ...
# 378964  9.062100e+11        640472  Main Insured            M   20.0
# 378965  9.078000e+11        939086  Main Insured            M   41.0
# 378966  9.079400e+11        855992  Main Insured            M   51.0
# 378967  9.079400e+11       1040858  Main Insured            M   52.0
# 378968  9.079400e+11       1076283  Main Insured            M   52.0
#
#        POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# ...

# %%
df.rename(columns = {'DISEASE_CHILD_CD':'DCC'}, inplace = True)
df.head(3)
# Out:
#       Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0  4.334000e+10        547344     Dependent            S    2.0
# 1  4.334000e+10        816550     Dependent            S    4.0
# 2  4.334000e+10        508897  Main Insured            MF  36.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
# 2        2017-07-01         2018-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE  ...     DCC PROC_PARENT_CD PROC_CHILD_CD  \
# 0             2018-04-09  ...    Z041            JLP          JLP1
# 1             2019-12-04  ...    J352            0CN       0CNQXZZ
# 2             2018-01-16  ...  Z98810            JLP          JLP1
#
#                                        HOSPITAL_NAME   CITY_NAME APV_TOTAL  \
# 0                       NON-PANEL HOPSITAL-ISLAMABAD   ISLAMABAD   82000.0
# ...

# %%
df = pd.concat([df, child_disease], axis=1)

# %%
#df = df.drop(columns=['Child_Disease_Name'])
df
# Out:
#            Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0       4.334000e+10        547344     Dependent            S    2.0
# 1       4.334000e+10        816550     Dependent            S    4.0
# 2       4.334000e+10        508897  Main Insured            MF  36.0
# 3       4.334000e+10        508900  Main Insured            MF  36.0
# 4       4.334000e+10        369250     Dependent            D    0.0
# ...              ...           ...           ...           ...   ...
# 378964  9.062100e+11        640472  Main Insured            M   20.0
# 378965  9.078000e+11        939086  Main Insured            M   41.0
# 378966  9.079400e+11        855992  Main Insured            M   51.0
# 378967  9.079400e+11       1040858  Main Insured            M   52.0
# 378968  9.079400e+11       1076283  Main Insured            M   52.0
#
#        POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# ...

# %%
df.rename(columns = {'DiseaseDescription':'Child_Disease_Name'}, inplace = True)

# %%
df.head(3)
# Out:
#       Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0  4.334000e+10        547344     Dependent            S    2.0
# 1  4.334000e+10        816550     Dependent            S    4.0
# 2  4.334000e+10        508897  Main Insured            MF  36.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
# 2        2017-07-01         2018-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE  ... PROC_CHILD_CD  \
# 0             2018-04-09  ...          JLP1
# 1             2019-12-04  ...       0CNQXZZ
# 2             2018-01-16  ...          JLP1
#
#                                        HOSPITAL_NAME   CITY_NAME APV_TOTAL  \
# 0                       NON-PANEL HOPSITAL-ISLAMABAD   ISLAMABAD   82000.0
# 1  GLOBAL HEALTH SERVICES-QUAID-E-AZAM INTERNATIO...   ISLAMABAD  122685.0
# ...

# %%
h1=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (1000001-2000000).csv')
h1.head()
# Out:
#    EMPLOYEE_ID LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH POLICY_START_DATE  \
# 0  52460003527    Dependent             S  26.0  17-FEB-92         01-JUL-18
# 1  52460003527    Dependent             S  24.0  18-MAY-94         01-JUL-18
# 2  52460003527    Dependent             D  20.0  20-MAY-99         01-JUL-19
# 3  52460003527    Dependent             S  25.0  18-MAY-94         01-JUL-19
# 4  52460003527    Dependent             S  27.0  17-FEB-92         01-JUL-19
#
#   POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0          30-JUN-19          0                 0
# 1          30-JUN-19          0                 0
# 2          30-JUN-20          0                 0
# 3          30-JUN-20          0                 0
# 4          30-JUN-20          0                 0

# %%
h2=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (2000001-3000000).csv')
h2.tail()
# Out:
#           EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE  AGE DATE_BIRTH  \
# 999995  1008540002943  Main Insured            MF   41  08-OCT-77
# 999996  1008540002944     Dependent             D   13  30-APR-06
# 999997  1008540002944     Dependent            FA   69  15-JUL-49
# 999998  1008540002944     Dependent            MO   62  01-JAN-57
# 999999  1008540002944  Main Insured             F   40  10-APR-79
#
#        POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 999995         01-NOV-18          31-OCT-19          1                 0
# 999996         01-NOV-18          31-OCT-19          1                 0
# 999997         01-NOV-18          31-OCT-19          1                 0
# 999998         01-NOV-18          31-OCT-19          1                 0
# 999999         01-NOV-18          31-OCT-19          1                 0

# %%
h3=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (3000001-4000000).csv')
h3.tail()
# Out:
#           EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH  \
# 999995  1017390004564  Main Insured             M  34.0  19-DEC-86
# 999996  1017390004564     Dependent             W  31.0  02-JUL-90
# 999997  1017390004564  Main Insured             M  35.0  19-DEC-86
# 999998  1017390004565     Dependent             D   5.0  12-MAR-14
# 999999  1017390004565  Main Insured             M  37.0  02-OCT-82
#
#        POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 999995         16-JUL-20          15-JUL-21      12500            470000
# 999996         16-JUL-21          15-JUL-22      12500            470000
# 999997         16-JUL-21          15-JUL-22      12500            470000
# 999998         16-JUL-19          15-JUL-20       8000            450000
# 999999         16-JUL-19          15-JUL-20       8000            450000

# %%
h4=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (4000001-5000000).csv')
h4.head()
# Out:
#      EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE  AGE DATE_BIRTH  \
# 0  1017390004565     Dependent             D    5  12-MAR-14
# 1  1017390004565  Main Insured             M   37  02-OCT-82
# 2  1017390004565     Dependent             W   38  20-DEC-81
# 3  1017390004565     Dependent             S   13  25-APR-06
# 4  1017390004565     Dependent             D    6  12-MAR-14
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0         16-JUL-19          15-JUL-20       8000            450000
# 1         16-JUL-19          15-JUL-20       8000            450000
# 2         16-JUL-19          15-JUL-20       8000            450000
# 3         16-JUL-19          15-JUL-20       8000            450000
# 4         16-JUL-20          15-JUL-21       9000            450000

# %%
h5=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (5000001-6000000).csv')
h5.head()
# Out:
#      EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE  AGE DATE_BIRTH  \
# 0  1025680000071  Main Insured             M   26  15-DEC-93
# 1  1025680000071     Dependent             W   26  07-JUL-94
# 2  1025680000071  Main Insured             M   27  15-DEC-93
# 3  1025680000072     Dependent             W   23  15-SEP-96
# 4  1025680000072  Main Insured             M   28  28-JUN-92
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0         01-JAN-20          31-DEC-20      33000           1000000
# 1         01-JAN-21          31-DEC-21      35970           1000000
# 2         01-JAN-21          31-DEC-21      35970           1000000
# 3         01-JAN-20          31-DEC-20      33000           1000000
# 4         01-JAN-20          31-DEC-20      33000           1000000

# %%
h6=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (6000001-7000000).csv')
h6.head()
# Out:
#      EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH  \
# 0  1042200001595  Main Insured             M  38.0  15-NOV-82
# 1  1042200001596  Main Insured             M  34.0  08-DEC-86
# 2  1042200001597  Main Insured             M  35.0  03-DEC-85
# 3  1042200001598  Main Insured             M  33.0  12-NOV-87
# 4  1042200001599  Main Insured             M  42.0  02-DEC-78
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0         01-JAN-21          31-DEC-21          1                 0
# 1         01-JAN-21          31-DEC-21          1                 0
# 2         01-JAN-21          31-DEC-21          1                 0
# 3         01-JAN-21          31-DEC-21          1                 0
# 4         01-JAN-21          31-DEC-21          1                 0

# %%
h7=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (7000001-8000000).csv')
h7.head()
# Out:
#    EMPLOYEE_ID LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH POLICY_START_DATE  \
# 0  11500021497    Dependent             D  25.0  01-JUL-96         01-JUL-21
# 1  11500021497    Dependent             D  29.0  02-JUN-92         01-JUL-21
# 2  11500021497    Dependent             S  19.0  02-FEB-02         01-JUL-21
# 3  11500021497    Dependent             S  23.0  01-JAN-99         01-JUL-21
# 4  11500021497    Dependent             W  54.0  01-JAN-68         01-JUL-21
#
#   POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0          30-JUN-22        700            200000
# 1          30-JUN-22        700            200000
# 2          30-JUN-22        700            200000
# 3          30-JUN-22        700            200000
# 4          30-JUN-22        700            200000

# %%
h8=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (8000001-9000000).csv')
h8.head()
# Out:
#     EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH  \
# 0  3.212000e+10     Dependent            MO  43.0  12-APR-75
# 1  3.212000e+10  Main Insured             M  28.0  20-JAN-90
# 2  3.212000e+10     Dependent             W  22.0  13-JAN-96
# 3  3.212000e+10     Dependent            MO  44.0  12-APR-75
# 4  3.212000e+10  Main Insured             M  29.0  20-JAN-90
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0         01-JUL-18          30-JUN-19     4000.0           35000.0
# 1         01-JUL-18          30-JUN-19     4000.0           35000.0
# 2         01-JUL-18          30-JUN-19     4000.0           35000.0
# 3         01-JUL-19          30-JUN-20     5000.0           35000.0
# 4         01-JUL-19          30-JUN-20     5000.0           35000.0

# %%
h9=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (9000001-10000000).csv')
h9.head()
# Out:
#    EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH POLICY_START_DATE  \
# 0  38840000155  Main Insured             M  24.0  29-NOV-95         15-MAR-20
# 1  38840000155  Main Insured             M  25.0  29-NOV-95         15-MAR-21
# 2  38840000156  Main Insured             M  31.0  19-FEB-89         15-MAR-20
# 3  38840000156  Main Insured             M  32.0  19-FEB-89         15-MAR-21
# 4  38840000157     Dependent             D   2.0  07-FEB-18         15-MAR-20
#
#   POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0          14-MAR-21       6500            200000
# 1          14-MAR-22       8500            300000
# 2          14-MAR-21       6500            200000
# 3          14-MAR-22       8500            300000
# 4          14-MAR-21       6500            200000

# %%
h10=pd.read_csv(r'D:\MS-material\IDS\Health Data\Latest Data Policy and Claims\Health Csv (10000001-onwards).csv')
h10.head()
# Out:
#    EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH POLICY_START_DATE  \
# 0  42480000055     Dependent             S   3.0  12-APR-18         01-AUG-21
# 1  42480000055  Main Insured            MF  38.0  05-JAN-84         01-AUG-21
# 2  42480000056     Dependent             S  14.0  29-NOV-02         01-AUG-16
# 3  42480000056  Main Insured             M  49.0  20-JAN-68         01-AUG-16
# 4  42480000056     Dependent             W  44.0  20-OCT-72         01-AUG-16
#
#   POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0          31-JUL-22      41250            750000
# 1          31-JUL-22      41250            750000
# 2          31-JUL-17       7000            100000
# 3          31-JUL-17       7000            100000
# 4          31-JUL-17       7000            100000

# %%
#h11=pd.read_csv(r'C:\Users\Hp\Desktop\FAST\Health Data\Latest Data Policy and Claims\h11.csv')
#h11.head()

# %%
df_health = pd.concat([h1,h2,h3,h4,h5,h6,h7,h8,h9,h10])
df_health
# Out:
#          EMPLOYEE_ID  LIFE_ASSURED RELATION_CODE   AGE DATE_BIRTH  \
# 0       5.246000e+10     Dependent             S  26.0  17-FEB-92
# 1       5.246000e+10     Dependent             S  24.0  18-MAY-94
# 2       5.246000e+10     Dependent             D  20.0  20-MAY-99
# 3       5.246000e+10     Dependent             S  25.0  18-MAY-94
# 4       5.246000e+10     Dependent             S  27.0  17-FEB-92
# ...              ...           ...           ...   ...        ...
# 278919  9.079600e+11     Dependent             S   0.0  03-FEB-17
# 278920  9.079600e+11  Main Insured             F  37.0  11-SEP-80
# 278921  9.079700e+11  Main Insured             M  22.0  19-OCT-95
# 278922  9.079800e+11  Main Insured             M  24.0  23-APR-93
# 278923  9.079900e+11  Main Insured             M  45.0  05-SEP-72
#
#        POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI
# 0              01-JUL-18          30-JUN-19        0.0               0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378969 entries, 0 to 378968
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Client_ID               378969 non-null  float64
#  1   CLAIM_REG_NO            378969 non-null  int64
#  2   LIFE_ASURED             378969 non-null  string
#  3   RELATION_CODE           378968 non-null  string
#  4   AGE                     378968 non-null  float64
#  5   POLICY_START_DATE       378969 non-null  datetime64[ns]
#  6   POLICY_EXPIRE_DATE      378969 non-null  datetime64[ns]
#  7   ROOM_RENT               378969 non-null  int64
#  8   TOTAL_LIMIT_INDI        378969 non-null  int64
#  9   PATIENT_ADMISSION_DATE  378969 non-null  datetime64[ns]
#  10  PATIENT_DISCHARGE_DATE  376042 non-null  datetime64[ns]
#  11  DISEASE_PARENT_CD       378969 non-null  string
#  12  DCC                     378969 non-null  string
# ...

# %%
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9278924 entries, 0 to 278923
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   EMPLOYEE_ID         float64
#  1   LIFE_ASSURED        object
#  2   RELATION_CODE       object
#  3   AGE                 float64
#  4   DATE_BIRTH          object
#  5   POLICY_START_DATE   object
#  6   POLICY_EXPIRE_DATE  object
#  7   ROOM_RENT           float64
#  8   TOTAL_LIMIT_INDI    float64
# dtypes: float64(4), object(5)
# memory usage: 707.9+ MB

# %%
df_health['LIFE_ASSURED']=df_health['LIFE_ASSURED'].astype('string')
df_health['LIFE_ASSURED'].dtype
# Out:
# StringDtype

# %%
df_health['RELATION_CODE']=df_health['RELATION_CODE'].astype('string')
df_health['RELATION_CODE'].dtype
# Out:
# StringDtype

# %%
df_health['POLICY_START_DATE']=pd.to_datetime(df_health['POLICY_START_DATE'])
df_health['POLICY_EXPIRE_DATE']=pd.to_datetime(df_health['POLICY_EXPIRE_DATE'])
df_health['DATE_BIRTH']=pd.to_datetime(df_health['DATE_BIRTH'])
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9278924 entries, 0 to 278923
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   EMPLOYEE_ID         float64
#  1   LIFE_ASSURED        string
#  2   RELATION_CODE       string
#  3   AGE                 float64
#  4   DATE_BIRTH          datetime64[ns]
#  5   POLICY_START_DATE   datetime64[ns]
#  6   POLICY_EXPIRE_DATE  datetime64[ns]
#  7   ROOM_RENT           float64
#  8   TOTAL_LIMIT_INDI    float64
# dtypes: datetime64[ns](3), float64(4), string(2)
# memory usage: 707.9 MB

# %%
df['Parent_Disease_Name']=df['Parent_Disease_Name'].astype('string')
df['Child_Procedure_Name']=df['Child_Procedure_Name'].astype('string')
df['Parent_Procedure_Name']=df['Parent_Procedure_Name'].astype('string')
df['Child_Disease_Name']=df['Child_Disease_Name'].astype('string')
df['DCC']=df['DCC'].astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378969 entries, 0 to 378968
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Client_ID               378969 non-null  float64
#  1   CLAIM_REG_NO            378969 non-null  int64
#  2   LIFE_ASURED             378969 non-null  string
#  3   RELATION_CODE           378968 non-null  string
#  4   AGE                     378968 non-null  float64
#  5   POLICY_START_DATE       378969 non-null  datetime64[ns]
#  6   POLICY_EXPIRE_DATE      378969 non-null  datetime64[ns]
#  7   ROOM_RENT               378969 non-null  int64
#  8   TOTAL_LIMIT_INDI        378969 non-null  int64
#  9   PATIENT_ADMISSION_DATE  378969 non-null  datetime64[ns]
#  10  PATIENT_DISCHARGE_DATE  376042 non-null  datetime64[ns]
#  11  DISEASE_PARENT_CD       378969 non-null  string
#  12  DCC                     378969 non-null  object
# ...

# %% [markdown]
# # Data Cleaning has been done. We now have two dataframes. 'df' has the claims.csv details.
# # 'df_health' dataframe has the merged 11 files with all the client and hospital details.

# %%
df.head(2)
# Out:
#       Client_ID  CLAIM_REG_NO LIFE_ASURED RELATION_CODE  AGE  \
# 0  4.334000e+10        547344   Dependent            S   2.0
# 1  4.334000e+10        816550   Dependent            S   4.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE  ... PROC_CHILD_CD  \
# 0             2018-04-09  ...          JLP1
# 1             2019-12-04  ...       0CNQXZZ
#
#                                        HOSPITAL_NAME  CITY_NAME APV_TOTAL  \
# 0                       NON-PANEL HOPSITAL-ISLAMABAD  ISLAMABAD   82000.0
# 1  GLOBAL HEALTH SERVICES-QUAID-E-AZAM INTERNATIO...  ISLAMABAD  122685.0
#
#                                  Parent_Disease_Name  \
# 0  Encounter for examination and observation for ...
# 1  Chronic diseases of tonsils and adenoids, Chro...
#
# ...

# %%
df.corr()
# Out:
#                   Client_ID  CLAIM_REG_NO       AGE  ROOM_RENT  \
# Client_ID          1.000000      0.531794  0.049496   0.083571
# CLAIM_REG_NO       0.531794      1.000000 -0.027916   0.083429
# AGE                0.049496     -0.027916  1.000000   0.128760
# ROOM_RENT          0.083571      0.083429  0.128760   1.000000
# TOTAL_LIMIT_INDI  -0.039546     -0.091706  0.162373   0.625876
# APV_TOTAL         -0.055074     -0.067020  0.016087  -0.034038
#
#                   TOTAL_LIMIT_INDI  APV_TOTAL
# Client_ID                -0.039546  -0.055074
# CLAIM_REG_NO             -0.091706  -0.067020
# AGE                       0.162373   0.016087
# ROOM_RENT                 0.625876  -0.034038
# TOTAL_LIMIT_INDI          1.000000   0.016900
# APV_TOTAL                 0.016900   1.000000

# %%
import seaborn as sns

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
from IPython.display import Image
Image("D:\MS-material\IDS\Health Data\picture.png")

# %%
df['CITY_NAME']
# Out:
# 0          ISLAMABAD
# 1          ISLAMABAD
# 2         RAWALPINDI
# 3         RAWALPINDI
# 4          ISLAMABAD
#              ...
# 378964       KARACHI
# 378965       KARACHI
# 378966       KARACHI
# 378967       KARACHI
# 378968       KARACHI
# Name: CITY_NAME, Length: 378969, dtype: string

# %%
Prediction of certain kinds of claims by monitoring the claims

# %%
df.head(5)
# Out:
#       Client_ID  CLAIM_REG_NO   LIFE_ASURED RELATION_CODE   AGE  \
# 0  4.334000e+10        547344     Dependent            S    2.0
# 1  4.334000e+10        816550     Dependent            S    4.0
# 2  4.334000e+10        508897  Main Insured            MF  36.0
# 3  4.334000e+10        508900  Main Insured            MF  36.0
# 4  4.334000e+10        369250     Dependent            D    0.0
#
#   POLICY_START_DATE POLICY_EXPIRE_DATE  ROOM_RENT  TOTAL_LIMIT_INDI  \
# 0        2017-07-01         2018-06-30      10000            400000
# 1        2019-07-01         2020-06-30      10000            400000
# 2        2017-07-01         2018-06-30      10000            400000
# 3        2017-07-01         2018-06-30      10000            400000
# 4        2016-07-01         2017-06-30      10000            400000
#
#   PATIENT_ADMISSION_DATE  ... PROC_CHILD_CD  \
# 0             2018-04-09  ...          JLP1
# 1             2019-12-04  ...       0CNQXZZ
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.apply(lambda x: x.nunique())
# Out:
# Client_ID                 102017
# CLAIM_REG_NO              378593
# LIFE_ASURED                    2
# RELATION_CODE                 11
# AGE                          145
# POLICY_START_DATE           1510
# POLICY_EXPIRE_DATE          1505
# ROOM_RENT                    394
# TOTAL_LIMIT_INDI             254
# PATIENT_ADMISSION_DATE      1826
# PATIENT_DISCHARGE_DATE      1858
# DISEASE_PARENT_CD           2892
# DCC                         8369
# PROC_PARENT_CD               583
# PROC_CHILD_CD               5116
# HOSPITAL_NAME                502
# CITY_NAME                    124
# APV_TOTAL                  11378
# Parent_Disease_Name         2883
# Child_Procedure_Name        5098
# Parent_Procedure_Name        580
# Child_Disease_Name             1
# DCC                        21915
# Child_Disease_Name         21532
# dtype: int64

# %%
categorical=['LIFE_ASURED','RELATION_CODE','CITY_NAME', 'Parent_Disease_Name',
              'HOSPITAL_NAME', 'Child_Procedure_Name', 'Parent_Procedure_Name']

# %%
numerical = [ 'AGE',
        'ROOM_RENT', 'TOTAL_LIMIT_INDI', 'APV_TOTAL']

# %%
x=df['CITY_NAME'].unique()
y=df['CLAIM_REG_NO'].unique()

print(x)
print(y)
# Out:
# <StringArray>
# [                'ISLAMABAD',                'RAWALPINDI',
#                  'HYDERABAD',                    'LAHORE',
#                   'PESHAWAR',                   'KARACHI',
#            'DERA ISMAILKHAN',                    'SUKKUR',
#                'SHEIKHUPURA',            'ALIPUR CHATTHA',
#  ...
#          'PAKISTAN-SONIKOTE',                 'DEEPALPUR',
#                'MIRPUR (AK)',                    'KAMOKI',
#            'MANDI BAHAUDDIN',                     'DIGRI',
#                    'KAMALIA',                   'CHUNIAN',
#             'KHANQAH SHARIF', 'PAKISTAN-ALIABAD - GILGIT']
# Length: 124, dtype: string
# [ 547344  816550  508897 ...  855992 1040858 1076283]

# %%
fig = sns.barplot(x, y,data = df)
fig.set(xlabel= 'Cities', ylabel= 'CLAIM_REG_NO')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-2331c44e704f> in <module>
# ----> 1 fig = sns.barplot(x, y,data = df)
#       2 fig.set(xlabel= 'Cities', ylabel= 'CLAIM_REG_NO')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
for cat in categorical:
    print(cat,'\n',df[cat].value_counts(),'\n')
# Out:
# LIFE_ASURED
#  Dependent       229406
# Main Insured    149563
# Name: LIFE_ASURED, dtype: Int64
#
# RELATION_CODE
#  M     129777
# W      73993
# S      64372
# D      46249
# MO     24287
# FA     15564
# F      11990
# MF      7802
# H       4928
# s          5
# w          1
# Name: RELATION_CODE, dtype: Int64
#
# CITY_NAME
#  KARACHI           181539
# LAHORE             80301
# ISLAMABAD          48887
# GILGIT             13690
# FAISALABAD          9979
#                    ...
# THATTA                 1
# MURIDKE                1
# DEEPALPUR              1
# CHUNIAN                1
# KHANQAH SHARIF         1
# Name: CITY_NAME, Length: 124, dtype: Int64
#
# Parent_Disease_Name
#  Encounter for examination and observation for other reasons, Encounter for examination and observation for other reasons    41058
# Jubilee Life,                                                                                                               34090
# ...

# %%
fig = plt.figure(figsize = (50,20))
axes = 32
for cat in categorical[0:7]:
    axes += 1
    fig.add_subplot(axes)
    sns.countplot(data =df, x = cat)
    plt.xlabel(cat,fontsize=30)
    plt.xticks(rotation=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-f1bb1ce8f702> in <module>
#       3 for cat in categorical[0:7]:
#       4     axes += 1
# ----> 5     fig.add_subplot(axes)
#       6     sns.countplot(data =df, x = cat)
#       7     plt.xlabel(cat,fontsize=30)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ...
